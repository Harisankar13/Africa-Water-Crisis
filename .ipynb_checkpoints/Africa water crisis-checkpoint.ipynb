# %%
from pandas_datareader import wb
import pandas as pd
import awoc

# %%
indicator = ['NY.GDP.PCAP.PP.CD', 'SI.POV.GINI', 'SE.XPD.TOTL.GD.ZS', 
             'SE.PRM.CMPT.FE.ZS','SE.PRM.CMPT.MA.ZS', 'EG.ELC.ACCS.ZS',
             'ER.H2O.FWTL.ZS', 'SH.XPD.CHEX.GD.ZS', 'SL.UEM.TOTL.FE.ZS',
             'SL.UEM.TOTL.MA.ZS'] # you can find the indicator code from https://data.worldbank.org/

# %% [markdown]
# Raw world bank data for the above indicators

# %%
df_wb_raw = wb.download(country='all', indicator=indicator, start=2011, end=2022)
df_wb_raw.head()
# Out:
#                                   NY.GDP.PCAP.PP.CD  SI.POV.GINI  \
# country                     year
# Africa Eastern and Southern 2021        3839.470058          NaN
#                             2020        3621.058106          NaN
#                             2019        3777.972368          NaN
#                             2018        3724.868177          NaN
#                             2017        3635.564622          NaN
#
#                                   SE.XPD.TOTL.GD.ZS  SE.PRM.CMPT.FE.ZS  \
# country                     year
# Africa Eastern and Southern 2021                NaN                NaN
#                             2020           4.608170          70.825378
#                             2019           4.600084          69.990547
#                             2018           4.834590          69.499100
#                             2017           4.862555          68.167793
#
#                                   SE.PRM.CMPT.MA.ZS  EG.ELC.ACCS.ZS  \
# country                     year
# Africa Eastern and Southern 2021                NaN             NaN
#                             2020          73.103210       45.609604
#                             2019          71.827660       44.073912
#                             2018          70.889862       42.880977
#                             2017          69.157753       40.092163
#
#                                   ER.H2O.FWTL.ZS  SH.XPD.CHEX.GD.ZS  \
# country                     year
# Africa Eastern and Southern 2021             NaN                NaN
#                             2020             NaN                NaN
#                             2019        4.929973           6.272034
#                             2018        4.928115           6.323236
#                             2017        4.881813           6.317424
#
#                                   SL.UEM.TOTL.FE.ZS  SL.UEM.TOTL.MA.ZS
# country                     year
# Africa Eastern and Southern 2021           8.495897           7.401659
#                             2020           8.120844           7.192637
#                             2019           7.620241           6.673629
#                             2018           7.417152           6.461407
#                             2017           7.455044           6.480417

# %% [markdown]
# Creating new dataframe to work on

# %%
df_wb = df_wb_raw.reset_index() 
df_wb = df_wb.rename(columns={'country':'Country', 'year':'Year', 
                              'NY.GDP.PCAP.PP.CD': 'Per Capita GDP', 
                              'SI.POV.GINI': 'GINI Index',
                              'SE.XPD.TOTL.GD.ZS':'% GDP on Edu',
                              'SE.PRM.CMPT.FE.ZS':'% Fem Pri Edu',
                              'SE.PRM.CMPT.MA.ZS': '% Male Pri Edu',
                              'EG.ELC.ACCS.ZS': 'Access to Electricity (% of pop)',
                              'ER.H2O.FWTL.ZS': '% Annual Freshwater Withdrawals (internal)',
                              'SH.XPD.CHEX.GD.ZS': '% of GDP on Health',
                              'SL.UEM.TOTL.FE.ZS': '% Unemp Fem',
                              'SL.UEM.TOTL.MA.ZS': '% Unemp Male'})
df_wb.head()
# Out:
#                        Country  Year  Per Capita GDP  GINI Index  \
# 0  Africa Eastern and Southern  2021     3839.470058         NaN
# 1  Africa Eastern and Southern  2020     3621.058106         NaN
# 2  Africa Eastern and Southern  2019     3777.972368         NaN
# 3  Africa Eastern and Southern  2018     3724.868177         NaN
# 4  Africa Eastern and Southern  2017     3635.564622         NaN
#
#    % GDP on Edu  % Fem Pri Edu  % Male Pri Edu  \
# 0           NaN            NaN             NaN
# 1      4.608170      70.825378       73.103210
# 2      4.600084      69.990547       71.827660
# 3      4.834590      69.499100       70.889862
# 4      4.862555      68.167793       69.157753
#
#    Access to Electricity (% of pop)  \
# 0                               NaN
# 1                         45.609604
# 2                         44.073912
# 3                         42.880977
# 4                         40.092163
#
#    % Annual Freshwater Withdrawals (internal)  % of GDP on Health  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                    4.929973            6.272034
# 3                                    4.928115            6.323236
# 4                                    4.881813            6.317424
#
#    % Unemp Fem  % Unemp Male
# 0     8.495897      7.401659
# 1     8.120844      7.192637
# 2     7.620241      6.673629
# 3     7.417152      6.461407
# 4     7.455044      6.480417

# %% [markdown]
# Extracting the data for only countries in Africa

# %%
my_world = awoc.AWOC() # Creating the class
countries_africa= my_world.get_countries_list_of('Africa')
df_country = pd.DataFrame (countries_africa, columns = ['Country'])
df_country = df_country.assign(Continent = 'Africa')
df_country.head()
# Out:
#         Country Continent
# 0       Algeria    Africa
# 1        Angola    Africa
# 2         Benin    Africa
# 3      Botswana    Africa
# 4  Burkina Faso    Africa

# %%
df_country['Country'].nunique() # number of countries
# Out:
# 58

# %% [markdown]
# Checking countries with different spellings

# %%
df_temp = df_wb.merge(df_country,on='Country', how='inner')
df_temp['Country'].nunique()
# Out:
# 47

# %%
temp_country = df_temp['Country'].unique().tolist()
missing = list(set(countries_africa) - set(temp_country))
print(missing)
# Out:
# ['Egypt', 'Democratic Republic of the Congo', 'Saint Helena', 'Mayotte', 'Ivory Coast', 'Reunion', 'Republic of the Congo', 'Cape Verde', 'Gambia', 'Swaziland', 'Western Sahara']

# %% [markdown]
# Renaming countries in df_country based on countries in world bank data(df_wb). Out of 11 missing countries, 5 countries had a different spelling and remaining 6 country data no available. Country spelling updated as given in the world bank data.

# %%
df_country.loc[df_country['Country']=='Egypt'] = 'Egypt, Arab Rep.'
df_country.loc[df_country['Country']=="Ivory Coast"] = "Cote d'Ivoire"
df_country.loc[df_country['Country']=='Republic of the Congo'] = 'Congo, Rep.'
df_country.loc[df_country['Country']=='Democratic Republic of the Congo'] = 'Congo, Dem. Rep.'
df_country.loc[df_country['Country']=='Gambia'] = 'Gambia, The'

# %%
df_wb = df_wb.merge(df_country,on='Country', how='inner') # merging columns
df_wb.head()
# Out:
#    Country  Year  Per Capita GDP  GINI Index  % GDP on Edu  % Fem Pri Edu  \
# 0  Algeria  2021    12128.274991         NaN           NaN            NaN
# 1  Algeria  2020    11438.691156         NaN      7.042397     103.344200
# 2  Algeria  2019    12118.004500         NaN      6.100360     101.582573
# 3  Algeria  2018    12006.010238         NaN      5.866350     105.625076
# 4  Algeria  2017    11809.483033         NaN      6.505380     105.750702
#
#    % Male Pri Edu  Access to Electricity (% of pop)  \
# 0             NaN                               NaN
# 1      103.970131                         99.804131
# 2      101.155350                         99.500000
# 3      104.681931                         99.697838
# 4      105.527252                         99.635490
#
#    % Annual Freshwater Withdrawals (internal)  % of GDP on Health  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                   87.152129            6.243371
# 3                                   87.152129            6.163026
# 4                                   87.152129            6.279384
#
#    % Unemp Fem  % Unemp Male Continent
# 0    20.475000         9.630    Africa
# 1    20.802000        10.211    Africa
# 2    18.679001         8.532    Africa
# 3    18.587999         8.442    Africa
# 4    18.487000         8.346    Africa

# %%
df_wb['Country'].nunique() # number of countries
# Out:
# 52
